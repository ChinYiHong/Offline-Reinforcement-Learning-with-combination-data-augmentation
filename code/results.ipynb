# %%
# cartpole experiment
# Adapted from the Reinforcement Learning (DQN) Tutorial by
# [Adam Paszke] https://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html
import gym
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import namedtuple
from torch.utils.data import Dataset, DataLoader
import numpy as np
import random
import random
import matplotlib.pyplot as plt
import matplotlib
import warnings
import time
from scipy.stats import mannwhitneyu
from tabulate import tabulate
import itertools
import math

warnings.filterwarnings("ignore", category=UserWarning)


# BATCH_SIZE is the number of transitions sampled from the replay buffer
# GAMMA makes rewards from the uncertain far future less
# important for our agent than the ones in the near future that it can be fairly confident about
# LR is the learning rate of the ``AdamW`` optimizer
# NUM_BATCH IS number of batch retrieve for training
# TAU is the update rate of the target network
BATCH_SIZE = 256
GAMMA = 0.99
LR = 0.0001
NUM_BATCH = 200
TAU = 0.0005
# files
CSV_FILE_BASE = "/content/drive/MyDrive/data/cartpole_data.csv"
CSV_FILE_ADV = "/content/drive/MyDrive/data/augmented_data_adv.csv"
CSV_FILE_GAU = "/content/drive/MyDrive/data/augmented_data_gaussian.csv"
CSV_FILE_UNI = "/content/drive/MyDrive/data/augmented_data_uniform.csv"
CSV_STACK_ADV = "/content/drive/MyDrive/data/combined_adv.csv"
CSV_STACK_GAU = "/content/drive/MyDrive/data/combined_gauss.csv"
CSV_STACK_UNI = "/content/drive/MyDrive/data/combined_uniform.csv"
CSV_STACK_UNI_ADV = "/content/drive/MyDrive/data/combined_adv_uniform.csv"
CSV_STACK_GAU_ADV = "/content/drive/MyDrive/data/combined_adv_gauss.csv"
CSV_COM_UNI_GAU = "/content/drive/MyDrive/data/add_gauss_uniform.csv"
CSV_COM_UNI_ADV = "/content/drive/MyDrive/data/add_adv_gauss.csv"
CSV_COM_GAU_ADV = "/content/drive/MyDrive/data/add_adv_uniform.csv"
CSV_COM_ALL = "/content/drive/MyDrive/data/add_all.csv"

Transition = namedtuple("Transition", ["state", "action", "next_state", "reward"])
# Check if GPU (CUDA) is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


class ReplayBufferDataset(Dataset):
    def __init__(self, csv_file):
        self.df = pd.read_csv(
            csv_file,
            dtype={
                "state0": float,
                "state1": float,
                "state2": float,
                "state3": float,
                "Action": int,
                "Reward": int,
                "Terminated": bool,
                "Truncated": bool,
            },
        )
        self.transitions = []

        for i in range(len(self.df)):
            state = self.df.loc[i, ["state0", "state1", "state2", "state3"]].values
            a = self.df.loc[i, "Action"]
            r = self.df.loc[i, "Reward"]
            t = self.df.loc[i, "Terminated"]
            tr = self.df.loc[i, "Truncated"]

            if t or tr:
                # Last step, termination/truncation = true
                next_state = [0.0, 0.0, 0.0, 0.0]  # Placeholder for last step
            else:
                next_state = self.df.loc[
                    i + 1, ["state0", "state1", "state2", "state3"]
                ].values

            self.transitions.append(Transition(state, a, next_state, r))

    def __len__(self):
        return len(self.transitions)

    def __getitem__(self, idx):
        transition = self.transitions[idx]
        return Transition(
            transition.state,
            transition.action,
            transition.next_state,
            transition.reward,
        )


# Replay buffer
class ReplayBuffer:
    def __init__(self, dataset):
        self.buffer = dataset.transitions
        self.idx = 0

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        return Transition(*zip(*batch))

    def __len__(self):
        return len(self.buffer)

class DQN(nn.Module):
    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()

        self.layer1 = nn.Linear(n_observations, BATCH_SIZE, bias=True)
        self.layer3 = nn.Linear(BATCH_SIZE, BATCH_SIZE, bias=True)  # the representation layer
        self.layer4 = nn.Linear(BATCH_SIZE, n_actions, bias=True)  # the prediction layer
        '''
        # xavier_uniform Weight Initialization
        nn.init.xavier_uniform_(self.layer1.weight)
        nn.init.xavier_uniform_(self.layer2.weight)
        nn.init.xavier_uniform_(self.layer3.weight)
        nn.init.xavier_uniform_(self.layer4.weight)
        '''
      # during optimization. Returns prediction
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer3(x))
        return self.layer4(x)


# function for printing results
def print_results_table(condition, label, values):
    table_data = [
        ["Mean", np.mean(values)],
        ["Median", np.median(values)],
        ["Standard Deviation", np.std(values)],
        ["Minimum", np.min(values)],
        ["Maximum", np.max(values)],
    ]
    print(f"{label} for {condition}:")
    print(tabulate(table_data, headers=["Metric", "Value"], tablefmt="grid"))

# function for training dqn
def train_dqn(dqn, target_net, memory, optimizer, device):
    start_time = time.time()
    q_values_list = []  # Store Q-values
    loss_list = []  # Store loss
    for transition in range(NUM_BATCH):
        # Sample batch from buffer
        batch = memory.sample(BATCH_SIZE)

        # Unpack batch
        states, actions, rewards, next_states = unpack_batch(batch)

        # Apply CUDA
        states, actions, rewards, next_states = (
            states.to(device),
            actions.to(device),
            rewards.to(device),
            next_states.to(device),
        )

        # Get Q values for current states
        q_values = dqn(states).gather(1, actions.view(-1, 1))

        # Calculate target Q values
        if next_states.size(0) > 0:
            with torch.no_grad():
                max_next_q = target_net(next_states).max(1)[0]
                target_q = rewards + GAMMA * max_next_q.detach()


        # Calculate loss
        '''
        loss_fn = nn.SmoothL1Loss()
        loss = loss_fn(q_values, target_q)
        '''
        # CQL Loss
        batch_size = BATCH_SIZE
        q_value_estimation_actions = dqn(states).max(1)[1].view(-1, 1)
        next_q_values = dqn(next_states).detach()
        next_q_values_selected = next_q_values.gather(1, q_value_estimation_actions)
        cql_temperature = 1
        cql_weight = 0.1
        loss = F.mse_loss(q_values, target_q) + cql_weight * F.mse_loss(cql_temperature * q_values, next_q_values_selected)

        # Optimize
        optimizer.zero_grad()
        loss.backward()

        # In-place gradient clipping
        torch.nn.utils.clip_grad_value_(dqn.parameters(), 100)

        optimizer.step()
        # Soft update of the target network's weights
        target_net_state_dict = target_net.state_dict()
        policy_net_state_dict = dqn.state_dict()
        for key in policy_net_state_dict:
            target_net_state_dict[key] = policy_net_state_dict[key]*TAU + target_net_state_dict[key]*(1-TAU)
        target_net.load_state_dict(target_net_state_dict)
        # Store Q-values and loss
        q_values_list.append(q_values.mean().item())
        loss_list.append(loss.item())
    end_time = time.time()
    elapsed_time = end_time - start_time
    return elapsed_time,q_values_list,loss_list

# function to extract batch from the buffers
def unpack_batch(batch):
    states = torch.cat(
        [
            torch.tensor(np.array(s).astype(np.float32)).float().unsqueeze(0)
            for s in batch.state
        ]
    )
    actions = torch.cat([torch.tensor(a).long().unsqueeze(0) for a in batch.action])
    rewards = torch.cat([torch.tensor(r).float().unsqueeze(0) for r in batch.reward])
    next_states = torch.cat(
        [
            torch.tensor(np.array(s).astype(np.float32)).float().unsqueeze(0)
            for s in batch.next_state
        ]
    )
    return states, actions, rewards, next_states

# function to evaluate results of testing phase
def evaluate_dqn(env, state, policy_net, target_net, device):
    episode_count = 0
    total_reward = 0
    solved = False

    while not solved and episode_count < 600:
        state = env.reset()
        state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
        episode_steps = 0
        while True:
            action = policy_net(state).max(1).indices.view(1, 1)

            next_state, reward, terminated, truncated, _ = env.step(action.item())
            next_state = torch.tensor(next_state, dtype=torch.float32, device=device).unsqueeze(0)
            total_reward += reward
            episode_steps += 1

            if terminated or truncated:
                break
            state = next_state

        if truncated:
            solved = True

        episode_count += 1

    total_reward = total_reward / episode_count
    return episode_count, total_reward

# function to reset weights of dqn
def weight_reset(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
        # Reset weights for convolutional and linear layers
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)

# main function for experiment
def run_experiment(num_trials, condition_name, csv_file, seed):
    print(f"Running experiment for condition: {condition_name}")
    print("Extracting from dataset....")
    dataset = ReplayBufferDataset(csv_file)
    print("Creating memory buffer....")
    memory = ReplayBuffer(dataset)
    # Initialize
    env = gym.make("CartPole-v1", new_step_api=True)
    # Get number of actions from gym action space
    action_dim = env.action_space.n
    # Get the number of state observations
    state = env.reset()
    state_dim = len(state)


    # initialize arrays to store results
    condition_episodes = []
    condition_rewards = []
    condition_times = []
    condition_q_values = []
    condition_losses = []
    for x in range(num_trials):
        # Set the seed for reproducibility within the trial
        new_seed = seed + x
        env.reset(seed=new_seed)
        np.random.seed(new_seed)
        torch.manual_seed(new_seed)
        random.seed(new_seed)
        # Initialize DQN, target network, and optimizer
        dqn = DQN(state_dim, action_dim).to(device)
        target_net = DQN(state_dim, action_dim).to(device)
        target_net.load_state_dict(dqn.state_dict())
        optimizer = optim.AdamW(dqn.parameters(), lr=LR, amsgrad=True)

        # Train the DQN
        print("Training DQN: ", condition_name)
        train_time,q_values,losses = train_dqn(dqn, target_net, memory, optimizer, device)
        condition_times.append(train_time)
        condition_q_values.append(q_values)
        condition_losses.append(losses)
        state = env.reset()
        # Evaluate the DQN
        episodes, rewards = evaluate_dqn(env, state, dqn, target_net, device)
        print(
            f"Solved in {episodes} episodes for condition: {condition_name}, trial: {x}"
        )
        condition_episodes.append(episodes)
        condition_rewards.append(rewards)
        print('rewards: ', rewards)
        print('time: ', train_time)
        # reset state for gym, weights for dqn
        state = env.reset()
        dqn.apply(weight_reset)
        target_net.apply(weight_reset)

    # visualize q values and loss
    visualize_Q_results(condition_q_values, condition_losses, condition_name)


    return condition_episodes, condition_rewards, condition_times


def perform_mannwhitneyu_test(
    condition1, result1, condition2, result2, alpha, num_comparisons
):
    # Mann-Whitney U Test for Rewards
    result = mannwhitneyu(result1["mean"], result2["mean"], alternative="greater")

    print(f"\nMann-Whitney U Test for {condition1} vs {condition2}:")
    print(f"U statistic: {result.statistic}")
    print(f"p-value: {result.pvalue}")

    # Bonferroni Correction
    adjusted_alpha = alpha / num_comparisons

    # Decide if statistically significant after Bonferroni Correction
    if result.pvalue < adjusted_alpha:
        print(
            f"The mean reward for {condition1} is statistically significantly greater than the mean reward for {condition2} after Bonferroni Correction (alpha={adjusted_alpha})."
        )
    else:
        print(
            f"The mean reward for {condition1} is NOT statistically significantly greater than the mean reward for {condition2} after Bonferroni Correction (alpha={adjusted_alpha})."
        )

def main():
    # setting up different conditions for testing
    '''
        "Baseline": CSV_FILE_BASE,
        "Gaussian": CSV_STACK_GAU,
        "Adv": CSV_STACK_ADV,
        "Uniform": CSV_STACK_UNI,
        "AdvUniform": CSV_STACK_UNI_ADV,
        "AdvGaussian": CSV_STACK_GAU_ADV,
        "COMB_GaussianUniform": CSV_COM_UNI_GAU,
        "COMB_AdvUniform": CSV_COM_UNI_ADV,
        "COMB_AdvGaussian": CSV_COM_GAU_ADV,
        "COMB_ALL": CSV_COM_ALL,
    '''
    conditions = {
        "Baseline": CSV_FILE_BASE,
        "Gaussian": CSV_STACK_GAU,
        "Adv": CSV_STACK_ADV,
        "Uniform": CSV_STACK_UNI,
        "AdvUni": CSV_STACK_UNI_ADV,
        "AdvGaus": CSV_STACK_GAU_ADV,
        "C_GausUni": CSV_COM_UNI_GAU,
        "C_AdvsUni": CSV_COM_UNI_ADV,
        "C_AdvGaus": CSV_COM_GAU_ADV,
        "C_ALL": CSV_COM_ALL,
    }
    print(conditions)
    num_trials = 5
    #776 is seed used
    #seed = np.random.randint(10000)  # Set a random seed for reproducibility across different conditions
    seed = 776
    print('seed: ', seed)
    episode_results = {}
    episode_rewards = {}
    episode_times = {}

    for condition, csv_file in conditions.items():

        condition_episodes, condition_rewards, condition_times = run_experiment(
            num_trials, condition, csv_file, seed
        )

        episode_results[condition] = {
            "mean": np.mean(condition_episodes, axis=0),
            "std": np.std(condition_episodes, axis=0),
        }

        episode_rewards[condition] = {
            "mean": np.mean(condition_rewards, axis=0),
            "std": np.std(condition_rewards, axis=0),
        }

        episode_times[condition] = {
            "mean": np.mean(condition_times),
            "std": np.std(condition_times),
        }

        print_results_table(condition, "Episodes", condition_episodes)
        print_results_table(condition, "Rewards", condition_rewards)
        print_results_table(condition, "Time", condition_times)


    # Statistical test
    num_comparisons = len(episode_rewards)
    alpha = 0.05


    for condition1, result1 in episode_rewards.items():
        for condition2, result2 in episode_rewards.items():
            # Avoid redundant comparisons and ensure each pair is tested only once
            if condition1 != condition2:
                # Perform Mann-Whitney U test
                perform_mannwhitneyu_test(condition1, result1, condition2, result2, alpha, num_comparisons)



    # Visualize results
    visualize_results(episode_results, "Episodes")
    visualize_results(episode_rewards, "Rewards")
    visualize_results(episode_times, "Time")



def visualize_results(results_dict, ylabel):
    colors = matplotlib.cm.rainbow(np.linspace(0, 1, len(results_dict)))
    plt.figure(figsize=(15, 8))

    conditions = list(results_dict.keys())
    mean_values = [result["mean"] for result in results_dict.values()]

    plt.bar(conditions, mean_values, color=colors, alpha=0.7)

    plt.title(f"Mean {ylabel} for Different Conditions")
    plt.xlabel("Conditions")
    plt.ylabel(f"Mean {ylabel}")
    plt.show()

def visualize_Q_results(q_values_list_per_condition, losses_list_per_condition, condition_name):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    for i, q_values_list in enumerate(q_values_list_per_condition):
        plt.plot(q_values_list, label=f'Trial {i + 1}')
    plt.title(f'Q-value Growth Over Iterations - {condition_name}')
    plt.xlabel('Iteration')
    plt.ylabel('Q-value')
    plt.legend()

    plt.subplot(1, 2, 2)
    for i, losses_list in enumerate(losses_list_per_condition):
        plt.plot(losses_list, label=f'Trial {i + 1}')
    plt.title(f'Loss Over Iterations - {condition_name}')
    plt.xlabel('Iteration')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# {'Baseline': '/content/drive/MyDrive/data/cartpole_data.csv', 'Gaussian': '/content/drive/MyDrive/data/combined_gauss.csv', 'Adv': '/content/drive/MyDrive/data/combined_adv.csv', 'Uniform': '/content/drive/MyDrive/data/combined_uniform.csv', 'AdvUni': '/content/drive/MyDrive/data/combined_adv_uniform.csv', 'AdvGaus': '/content/drive/MyDrive/data/combined_adv_gauss.csv', 'C_GausUni': '/content/drive/MyDrive/data/add_gauss_uniform.csv', 'C_AdvsUni': '/content/drive/MyDrive/data/add_adv_gauss.csv', 'C_AdvGaus': '/content/drive/MyDrive/data/add_adv_uniform.csv', 'C_ALL': '/content/drive/MyDrive/data/add_all.csv'}
# seed:  776
# Running experiment for condition: Baseline
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  Baseline
# Solved in 600 episodes for condition: Baseline, trial: 0
# rewards:  31.813333333333333
# time:  2.7888782024383545
# Training DQN:  Baseline
# Solved in 10 episodes for condition: Baseline, trial: 1
# rewards:  102.1
# time:  2.7258198261260986
# Training DQN:  Baseline
# Solved in 600 episodes for condition: Baseline, trial: 2
# rewards:  63.065
# time:  3.5149269104003906
# Training DQN:  Baseline
# Solved in 3 episodes for condition: Baseline, trial: 3
# rewards:  385.3333333333333
# time:  2.8076677322387695
# Training DQN:  Baseline
# Solved in 2 episodes for condition: Baseline, trial: 4
# rewards:  332.5
# time:  2.7787270545959473
# Episodes for Baseline:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               | 243     |
# +--------------------+---------+
# | Median             |  10     |
# +--------------------+---------+
# | Standard Deviation | 291.502 |
# +--------------------+---------+
# | Minimum            |   2     |
# +--------------------+---------+
# | Maximum            | 600     |
# +--------------------+---------+
# Rewards for Baseline:
# +--------------------+----------+
# | Metric             |    Value |
# +====================+==========+
# | Mean               | 182.962  |
# +--------------------+----------+
# | Median             | 102.1    |
# +--------------------+----------+
# | Standard Deviation | 146.339  |
# +--------------------+----------+
# | Minimum            |  31.8133 |
# +--------------------+----------+
# | Maximum            | 385.333  |
# +--------------------+----------+
# Time for Baseline:
# +--------------------+----------+
# | Metric             |    Value |
# +====================+==========+
# | Mean               | 2.9232   |
# +--------------------+----------+
# | Median             | 2.78888  |
# +--------------------+----------+
# | Standard Deviation | 0.297107 |
# +--------------------+----------+
# | Minimum            | 2.72582  |
# +--------------------+----------+
# | Maximum            | 3.51493  |
# +--------------------+----------+
# Running experiment for condition: Gaussian
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  Gaussian
# Solved in 600 episodes for condition: Gaussian, trial: 0
# rewards:  35.12166666666667
# time:  3.3472414016723633
# Training DQN:  Gaussian
# Solved in 10 episodes for condition: Gaussian, trial: 1
# rewards:  99.1
# time:  2.8171842098236084
# Training DQN:  Gaussian
# Solved in 600 episodes for condition: Gaussian, trial: 2
# rewards:  68.77166666666666
# time:  2.787407398223877
# Training DQN:  Gaussian
# Solved in 3 episodes for condition: Gaussian, trial: 3
# rewards:  410.6666666666667
# time:  2.8281760215759277
# Training DQN:  Gaussian
# Solved in 226 episodes for condition: Gaussian, trial: 4
# rewards:  131.74778761061947
# time:  2.8625729084014893
# Episodes for Gaussian:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               | 287.8   |
# +--------------------+---------+
# | Median             | 226     |
# +--------------------+---------+
# | Standard Deviation | 267.223 |
# +--------------------+---------+
# | Minimum            |   3     |
# +--------------------+---------+
# | Maximum            | 600     |
# +--------------------+---------+
# Rewards for Gaussian:
# +--------------------+----------+
# | Metric             |    Value |
# +====================+==========+
# | Mean               | 149.082  |
# +--------------------+----------+
# | Median             |  99.1    |
# +--------------------+----------+
# | Standard Deviation | 134.657  |
# +--------------------+----------+
# | Minimum            |  35.1217 |
# +--------------------+----------+
# | Maximum            | 410.667  |
# +--------------------+----------+
# Time for Gaussian:
# +--------------------+----------+
# | Metric             |    Value |
# +====================+==========+
# | Mean               | 2.92852  |
# +--------------------+----------+
# | Median             | 2.82818  |
# +--------------------+----------+
# | Standard Deviation | 0.210739 |
# +--------------------+----------+
# | Minimum            | 2.78741  |
# +--------------------+----------+
# | Maximum            | 3.34724  |
# +--------------------+----------+
# Running experiment for condition: Adv
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  Adv
# Solved in 600 episodes for condition: Adv, trial: 0
# rewards:  34.985
# time:  2.8657026290893555
# Training DQN:  Adv
# Solved in 10 episodes for condition: Adv, trial: 1
# rewards:  99.1
# time:  2.8377981185913086
# Training DQN:  Adv
# Solved in 600 episodes for condition: Adv, trial: 2
# rewards:  68.8
# time:  3.596588373184204
# Training DQN:  Adv
# Solved in 1 episodes for condition: Adv, trial: 3
# rewards:  500.0
# time:  2.813143014907837
# Training DQN:  Adv
# Solved in 226 episodes for condition: Adv, trial: 4
# rewards:  132.0486725663717
# time:  2.9451165199279785
# Episodes for Adv:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |  287.4  |
# +--------------------+---------+
# | Median             |  226    |
# +--------------------+---------+
# | Standard Deviation |  267.65 |
# +--------------------+---------+
# | Minimum            |    1    |
# +--------------------+---------+
# | Maximum            |  600    |
# +--------------------+---------+
# Rewards for Adv:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               | 166.987 |
# +--------------------+---------+
# | Median             |  99.1   |
# +--------------------+---------+
# | Standard Deviation | 169.583 |
# +--------------------+---------+
# | Minimum            |  34.985 |
# +--------------------+---------+
# | Maximum            | 500     |
# +--------------------+---------+
# Time for Adv:
# +--------------------+----------+
# | Metric             |    Value |
# +====================+==========+
# | Mean               | 3.01167  |
# +--------------------+----------+
# | Median             | 2.8657   |
# +--------------------+----------+
# | Standard Deviation | 0.295807 |
# +--------------------+----------+
# | Minimum            | 2.81314  |
# +--------------------+----------+
# | Maximum            | 3.59659  |
# +--------------------+----------+
# Running experiment for condition: Uniform
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  Uniform
# Solved in 600 episodes for condition: Uniform, trial: 0
# rewards:  34.97666666666667
# time:  2.75958514213562
# Training DQN:  Uniform
# Solved in 10 episodes for condition: Uniform, trial: 1
# rewards:  99.1
# time:  3.394284248352051
# Training DQN:  Uniform
# Solved in 600 episodes for condition: Uniform, trial: 2
# rewards:  68.86333333333333
# time:  3.470069646835327
# Training DQN:  Uniform
# Solved in 1 episodes for condition: Uniform, trial: 3
# rewards:  500.0
# time:  2.840989589691162
# Training DQN:  Uniform
# Solved in 226 episodes for condition: Uniform, trial: 4
# rewards:  132.02212389380531
# time:  4.021420478820801
# Episodes for Uniform:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |  287.4  |
# +--------------------+---------+
# | Median             |  226    |
# +--------------------+---------+
# | Standard Deviation |  267.65 |
# +--------------------+---------+
# | Minimum            |    1    |
# +--------------------+---------+
# | Maximum            |  600    |
# +--------------------+---------+
# Rewards for Uniform:
# +--------------------+----------+
# | Metric             |    Value |
# +====================+==========+
# | Mean               | 166.992  |
# +--------------------+----------+
# | Median             |  99.1    |
# +--------------------+----------+
# | Standard Deviation | 169.578  |
# +--------------------+----------+
# | Minimum            |  34.9767 |
# +--------------------+----------+
# | Maximum            | 500      |
# +--------------------+----------+
# Time for Uniform:
# +--------------------+----------+
# | Metric             |    Value |
# +====================+==========+
# | Mean               | 3.29727  |
# +--------------------+----------+
# | Median             | 3.39428  |
# +--------------------+----------+
# | Standard Deviation | 0.460644 |
# +--------------------+----------+
# | Minimum            | 2.75959  |
# +--------------------+----------+
# | Maximum            | 4.02142  |
# +--------------------+----------+
# Running experiment for condition: AdvUni
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  AdvUni
# Solved in 600 episodes for condition: AdvUni, trial: 0
# rewards:  35.041666666666664
# time:  3.294429063796997
# Training DQN:  AdvUni
# Solved in 10 episodes for condition: AdvUni, trial: 1
# rewards:  99.1
# time:  2.8128890991210938
# Training DQN:  AdvUni
# Solved in 600 episodes for condition: AdvUni, trial: 2
# rewards:  68.83
# time:  2.7874977588653564
# Training DQN:  AdvUni
# Solved in 1 episodes for condition: AdvUni, trial: 3
# rewards:  500.0
# time:  2.699132204055786
# Training DQN:  AdvUni
# Solved in 226 episodes for condition: AdvUni, trial: 4
# rewards:  131.86725663716814
# time:  2.864711046218872
# Episodes for AdvUni:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |  287.4  |
# +--------------------+---------+
# | Median             |  226    |
# +--------------------+---------+
# | Standard Deviation |  267.65 |
# +--------------------+---------+
# | Minimum            |    1    |
# +--------------------+---------+
# | Maximum            |  600    |
# +--------------------+---------+
# Rewards for AdvUni:
# +--------------------+----------+
# | Metric             |    Value |
# +====================+==========+
# | Mean               | 166.968  |
# +--------------------+----------+
# | Median             |  99.1    |
# +--------------------+----------+
# | Standard Deviation | 169.578  |
# +--------------------+----------+
# | Minimum            |  35.0417 |
# +--------------------+----------+
# | Maximum            | 500      |
# +--------------------+----------+
# Time for AdvUni:
# +--------------------+----------+
# | Metric             |    Value |
# +====================+==========+
# | Mean               | 2.89173  |
# +--------------------+----------+
# | Median             | 2.81289  |
# +--------------------+----------+
# | Standard Deviation | 0.208361 |
# +--------------------+----------+
# | Minimum            | 2.69913  |
# +--------------------+----------+
# | Maximum            | 3.29443  |
# +--------------------+----------+
# Running experiment for condition: AdvGaus
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  AdvGaus
# Solved in 600 episodes for condition: AdvGaus, trial: 0
# rewards:  35.005
# time:  2.8109471797943115
# Training DQN:  AdvGaus
# Solved in 10 episodes for condition: AdvGaus, trial: 1
# rewards:  99.1
# time:  3.3112335205078125
# Training DQN:  AdvGaus
# Solved in 600 episodes for condition: AdvGaus, trial: 2
# rewards:  68.79833333333333
# time:  3.1398844718933105
# Training DQN:  AdvGaus
# Solved in 1 episodes for condition: AdvGaus, trial: 3
# rewards:  500.0
# time:  2.935365676879883
# Training DQN:  AdvGaus
# Solved in 226 episodes for condition: AdvGaus, trial: 4
# rewards:  131.93805309734512
# time:  3.579463243484497
# Episodes for AdvGaus:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |  287.4  |
# +--------------------+---------+
# | Median             |  226    |
# +--------------------+---------+
# | Standard Deviation |  267.65 |
# +--------------------+---------+
# | Minimum            |    1    |
# +--------------------+---------+
# | Maximum            |  600    |
# +--------------------+---------+
# Rewards for AdvGaus:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               | 166.968 |
# +--------------------+---------+
# | Median             |  99.1   |
# +--------------------+---------+
# | Standard Deviation | 169.585 |
# +--------------------+---------+
# | Minimum            |  35.005 |
# +--------------------+---------+
# | Maximum            | 500     |
# +--------------------+---------+
# Time for AdvGaus:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               | 3.15538 |
# +--------------------+---------+
# | Median             | 3.13988 |
# +--------------------+---------+
# | Standard Deviation | 0.27255 |
# +--------------------+---------+
# | Minimum            | 2.81095 |
# +--------------------+---------+
# | Maximum            | 3.57946 |
# +--------------------+---------+
# Running experiment for condition: C_GausUni
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  C_GausUni
# Solved in 600 episodes for condition: C_GausUni, trial: 0
# rewards:  34.69166666666667
# time:  3.3867151737213135
# Training DQN:  C_GausUni
# Solved in 47 episodes for condition: C_GausUni, trial: 1
# rewards:  112.59574468085107
# time:  2.771609306335449
# Training DQN:  C_GausUni
# Solved in 600 episodes for condition: C_GausUni, trial: 2
# rewards:  61.156666666666666
# time:  3.0883283615112305
# Training DQN:  C_GausUni
# Solved in 3 episodes for condition: C_GausUni, trial: 3
# rewards:  240.33333333333334
# time:  2.739579439163208
# Training DQN:  C_GausUni
# Solved in 8 episodes for condition: C_GausUni, trial: 4
# rewards:  208.625
# time:  2.792544364929199
# Episodes for C_GausUni:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               | 251.6   |
# +--------------------+---------+
# | Median             |  47     |
# +--------------------+---------+
# | Standard Deviation | 284.875 |
# +--------------------+---------+
# | Minimum            |   3     |
# +--------------------+---------+
# | Maximum            | 600     |
# +--------------------+---------+
# Rewards for C_GausUni:
# +--------------------+----------+
# | Metric             |    Value |
# +====================+==========+
# | Mean               | 131.48   |
# +--------------------+----------+
# | Median             | 112.596  |
# +--------------------+----------+
# | Standard Deviation |  80.5858 |
# +--------------------+----------+
# | Minimum            |  34.6917 |
# +--------------------+----------+
# | Maximum            | 240.333  |
# +--------------------+----------+
# Time for C_GausUni:
# +--------------------+----------+
# | Metric             |    Value |
# +====================+==========+
# | Mean               | 2.95576  |
# +--------------------+----------+
# | Median             | 2.79254  |
# +--------------------+----------+
# | Standard Deviation | 0.249231 |
# +--------------------+----------+
# | Minimum            | 2.73958  |
# +--------------------+----------+
# | Maximum            | 3.38672  |
# +--------------------+----------+
# Running experiment for condition: C_AdvsUni
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  C_AdvsUni
# Solved in 600 episodes for condition: C_AdvsUni, trial: 0
# rewards:  34.7
# time:  2.8310108184814453
# Training DQN:  C_AdvsUni
# Solved in 47 episodes for condition: C_AdvsUni, trial: 1
# rewards:  112.70212765957447
# time:  3.466294288635254
# Training DQN:  C_AdvsUni
# Solved in 600 episodes for condition: C_AdvsUni, trial: 2
# rewards:  61.13666666666666
# time:  2.8724558353424072
# Training DQN:  C_AdvsUni
# Solved in 3 episodes for condition: C_AdvsUni, trial: 3
# rewards:  344.0
# time:  3.0567469596862793
# Training DQN:  C_AdvsUni
# Solved in 41 episodes for condition: C_AdvsUni, trial: 4
# rewards:  181.09756097560975
# time:  3.412036418914795
# Episodes for C_AdvsUni:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               | 258.2   |
# +--------------------+---------+
# | Median             |  47     |
# +--------------------+---------+
# | Standard Deviation | 279.486 |
# +--------------------+---------+
# | Minimum            |   3     |
# +--------------------+---------+
# | Maximum            | 600     |
# +--------------------+---------+
# Rewards for C_AdvsUni:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               | 146.727 |
# +--------------------+---------+
# | Median             | 112.702 |
# +--------------------+---------+
# | Standard Deviation | 110.573 |
# +--------------------+---------+
# | Minimum            |  34.7   |
# +--------------------+---------+
# | Maximum            | 344     |
# +--------------------+---------+
# Time for C_AdvsUni:
# +--------------------+----------+
# | Metric             |    Value |
# +====================+==========+
# | Mean               | 3.12771  |
# +--------------------+----------+
# | Median             | 3.05675  |
# +--------------------+----------+
# | Standard Deviation | 0.265971 |
# +--------------------+----------+
# | Minimum            | 2.83101  |
# +--------------------+----------+
# | Maximum            | 3.46629  |
# +--------------------+----------+
# Running experiment for condition: C_AdvGaus
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  C_AdvGaus
# Solved in 600 episodes for condition: C_AdvGaus, trial: 0
# rewards:  34.69166666666667
# time:  3.6342403888702393
# Training DQN:  C_AdvGaus
# Solved in 47 episodes for condition: C_AdvGaus, trial: 1
# rewards:  112.59574468085107
# time:  2.9586546421051025
# Training DQN:  C_AdvGaus
# Solved in 600 episodes for condition: C_AdvGaus, trial: 2
# rewards:  61.156666666666666
# time:  2.952428102493286
# Training DQN:  C_AdvGaus
# Solved in 3 episodes for condition: C_AdvGaus, trial: 3
# rewards:  240.33333333333334
# time:  2.8846359252929688
# Training DQN:  C_AdvGaus
# Solved in 8 episodes for condition: C_AdvGaus, trial: 4
# rewards:  208.625
# time:  2.9316177368164062
# Episodes for C_AdvGaus:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               | 251.6   |
# +--------------------+---------+
# | Median             |  47     |
# +--------------------+---------+
# | Standard Deviation | 284.875 |
# +--------------------+---------+
# | Minimum            |   3     |
# +--------------------+---------+
# | Maximum            | 600     |
# +--------------------+---------+
# Rewards for C_AdvGaus:
# +--------------------+----------+
# | Metric             |    Value |
# +====================+==========+
# | Mean               | 131.48   |
# +--------------------+----------+
# | Median             | 112.596  |
# +--------------------+----------+
# | Standard Deviation |  80.5858 |
# +--------------------+----------+
# | Minimum            |  34.6917 |
# +--------------------+----------+
# | Maximum            | 240.333  |
# +--------------------+----------+
# Time for C_AdvGaus:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               | 3.07232 |
# +--------------------+---------+
# | Median             | 2.95243 |
# +--------------------+---------+
# | Standard Deviation | 0.28216 |
# +--------------------+---------+
# | Minimum            | 2.88464 |
# +--------------------+---------+
# | Maximum            | 3.63424 |
# +--------------------+---------+
# Running experiment for condition: C_ALL
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  C_ALL
# Solved in 600 episodes for condition: C_ALL, trial: 0
# rewards:  36.943333333333335
# time:  3.6020874977111816
# Training DQN:  C_ALL
# Solved in 600 episodes for condition: C_ALL, trial: 1
# rewards:  70.39333333333333
# time:  2.893561601638794
# Training DQN:  C_ALL
# Solved in 600 episodes for condition: C_ALL, trial: 2
# rewards:  67.37
# time:  2.9088990688323975
# Training DQN:  C_ALL
# Solved in 1 episodes for condition: C_ALL, trial: 3
# rewards:  500.0
# time:  3.831775188446045
# Training DQN:  C_ALL
# Solved in 2 episodes for condition: C_ALL, trial: 4
# rewards:  331.5
# time:  2.939391613006592
# Episodes for C_ALL:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               | 360.6   |
# +--------------------+---------+
# | Median             | 600     |
# +--------------------+---------+
# | Standard Deviation | 293.204 |
# +--------------------+---------+
# | Minimum            |   1     |
# +--------------------+---------+
# | Maximum            | 600     |
# +--------------------+---------+
# Rewards for C_ALL:
# +--------------------+----------+
# | Metric             |    Value |
# +====================+==========+
# | Mean               | 201.241  |
# +--------------------+----------+
# | Median             |  70.3933 |
# +--------------------+----------+
# | Standard Deviation | 183.445  |
# +--------------------+----------+
# | Minimum            |  36.9433 |
# +--------------------+----------+
# | Maximum            | 500      |
# +--------------------+----------+
# Time for C_ALL:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               | 3.23514 |
# +--------------------+---------+
# | Median             | 2.93939 |
# +--------------------+---------+
# | Standard Deviation | 0.4003  |
# +--------------------+---------+
# | Minimum            | 2.89356 |
# +--------------------+---------+
# | Maximum            | 3.83178 |
# +--------------------+---------+
#
# Mann-Whitney U Test for Baseline vs Gaussian:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Baseline vs Adv:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Baseline vs Uniform:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Baseline vs AdvUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Baseline vs AdvGaus:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Baseline vs C_GausUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Baseline vs C_AdvsUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Baseline vs C_AdvGaus:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Baseline vs C_ALL:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs Adv:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs Uniform:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs AdvUni:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs AdvGaus:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs C_GausUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs C_AdvsUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs C_AdvGaus:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs C_ALL:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs Gaussian:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs Uniform:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs AdvUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs AdvGaus:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs C_GausUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs C_AdvsUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs C_AdvGaus:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs C_ALL:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs Gaussian:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs Adv:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs AdvUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs AdvGaus:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs C_GausUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs C_AdvsUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs C_AdvGaus:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs C_ALL:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs Gaussian:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs Adv:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs Uniform:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs AdvGaus:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs C_GausUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs C_AdvsUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs C_AdvGaus:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs C_ALL:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs Gaussian:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs Adv:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs Uniform:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs AdvUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs C_GausUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs C_AdvsUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs C_AdvGaus:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs C_ALL:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs Gaussian:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs Adv:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs Uniform:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs AdvUni:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs AdvGaus:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs C_AdvsUni:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs C_AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs C_ALL:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs Gaussian:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs Adv:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs Uniform:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs AdvUni:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs AdvGaus:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs C_GausUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs C_AdvGaus:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs C_ALL:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs Gaussian:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs Adv:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs Uniform:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs AdvUni:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs AdvGaus:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs C_GausUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs C_AdvsUni:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs C_ALL:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs Baseline:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs Gaussian:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs Adv:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs Uniform:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs AdvUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs AdvGaus:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs C_GausUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs C_AdvsUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs C_AdvGaus:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).

# %%
# hyperparameter tuning for cartpole
# Adapted from the Reinforcement Learning (DQN) Tutorial by
# [Adam Paszke] https://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html
import gym
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import namedtuple
from torch.utils.data import Dataset, DataLoader
import numpy as np
import random
import random
import matplotlib.pyplot as plt
import matplotlib
import warnings
import time
from scipy.stats import mannwhitneyu
from tabulate import tabulate
import itertools
import math
import torch.nn.functional as F

warnings.filterwarnings("ignore", category=UserWarning)



Transition = namedtuple("Transition", ["state", "action", "next_state", "reward", "terminated"])
# Check if GPU (CUDA) is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


class ReplayBufferDataset(Dataset):
    def __init__(self, csv_file):
        self.df = pd.read_csv(
            csv_file,
            dtype={
                "state0": float,
                "state1": float,
                "state2": float,
                "state3": float,
                "Action": int,
                "Reward": int,
                "Terminated": bool,
                "Truncated": bool,
            },
        )
        self.transitions = []

        for i in range(len(self.df)):
            state = self.df.loc[i, ["state0", "state1", "state2", "state3"]].values
            a = self.df.loc[i, "Action"]
            r = self.df.loc[i, "Reward"]
            t = self.df.loc[i, "Terminated"]
            tr = self.df.loc[i, "Truncated"]

            if t or tr:
                # Last step, termination/truncation = true
                next_state = [0,0,0,0] # Placeholder for last step
            else:
                next_state = self.df.loc[
                    i + 1, ["state0", "state1", "state2", "state3"]
                ].values

            self.transitions.append(Transition(state, a, next_state, r, t))

    def __len__(self):
        return len(self.transitions)

    def __getitem__(self, idx):
        transition = self.transitions[idx]
        return Transition(
            transition.state,
            transition.action,
            transition.next_state,
            transition.reward,
            transition.terminated,
        )


# Replay buffer
class ReplayBuffer:
    def __init__(self, dataset):
        self.buffer = dataset.transitions
        self.idx = 0

    def push(self, *args):
        """Save a transition"""
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        return Transition(*zip(*batch))

    def __len__(self):
        return len(self.buffer)




class DQN(nn.Module):
    def __init__(self, n_observations, n_actions, selected_hyperparameters):
        super(DQN, self).__init__()

        self.layer1 = nn.Linear(n_observations, selected_hyperparameters['BATCH_SIZE'], bias=True)
        self.layer2 = nn.Linear(selected_hyperparameters['BATCH_SIZE'], selected_hyperparameters['BATCH_SIZE'], bias=True)
        #self.layer3 = nn.Linear(selected_hyperparameters['BATCH_SIZE'], selected_hyperparameters['BATCH_SIZE'], bias=True) # the representation layer
        self.layer4 = nn.Linear(selected_hyperparameters['BATCH_SIZE'], n_actions, bias=True)  # the prediction layer
        '''
        # xavier_uniform Weight Initialization: Set the initial values of the weights in a neural network,
        #aiming to address issues like vanishing or exploding gradients
        nn.init.xavier_uniform_(self.layer1.weight)
        nn.init.xavier_uniform_(self.layer2.weight)
        nn.init.xavier_uniform_(self.layer3.weight)
        nn.init.xavier_uniform_(self.layer4.weight)
        '''
      # during optimization. Returns prediction
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        #x = F.relu(self.layer3(x))
        return self.layer4(x)




# function for printing results
def print_results_table(condition, label, values):
    table_data = [
        ["Mean", np.mean(values)],
        ["Median", np.median(values)],
        ["Standard Deviation", np.std(values)],
        ["Minimum", np.min(values)],
        ["Maximum", np.max(values)],
    ]
    print(f"{label} for {condition}:")
    print(tabulate(table_data, headers=["Metric", "Value"], tablefmt="grid"))


# function for training dqn
def train_dqn(dqn, target_net, memory, optimizer, device, selected_hyperparameters):
    start_time = time.time()
    q_values_list = []  # Store Q-values
    loss_list = []  # Store loss
    for transition in range(selected_hyperparameters['BATCH_NUM']):
        # Sample batch from buffer
        batch = memory.sample(selected_hyperparameters['BATCH_SIZE'])

        # Unpack batch
        states, actions, rewards, next_states = unpack_batch(batch)

        # Apply CUDA
        states, actions, rewards, next_states = (
            states.to(device),
            actions.to(device),
            rewards.to(device),
            next_states.to(device),
        )

        # Get Q values for current states
        q_values = dqn(states).gather(1, actions.view(-1, 1))

        # Calculate target Q values
        with torch.no_grad():
            max_next_q = target_net(next_states).max(1)[0]
            target_q = rewards + selected_hyperparameters['GAMMA'] * max_next_q.detach()


        # Calculate loss
        '''
        loss_fn = nn.SmoothL1Loss()
        loss = loss_fn(q_values, target_q)
        '''
        # CQL Loss
        batch_size = selected_hyperparameters['BATCH_SIZE']
        q_value_estimation_actions = dqn(states).max(1)[1].view(-1, 1)
        next_q_values = dqn(next_states).detach()
        next_q_values_selected = next_q_values.gather(1, q_value_estimation_actions)
        cql_temperature = selected_hyperparameters['cql_temperature']
        cql_weight = selected_hyperparameters['cql_weight']
        loss = F.mse_loss(q_values, target_q) + cql_weight * F.mse_loss(cql_temperature * q_values, next_q_values_selected)

        # Optimize
        optimizer.zero_grad()
        loss.backward()
        max_norm = 100

        # Clip gradients to a maximum norm
        torch.nn.utils.clip_grad_value_(dqn.parameters(), max_norm)

        optimizer.step()

        # Soft update of the target network's weights
        target_net_state_dict = target_net.state_dict()
        policy_net_state_dict = dqn.state_dict()
        TAU = selected_hyperparameters['TAU']
        for key in policy_net_state_dict:
            target_net_state_dict[key] = policy_net_state_dict[key]*TAU + target_net_state_dict[key]*(1-TAU)
        target_net.load_state_dict(target_net_state_dict)
        # Store Q-values and loss
        q_values_list.append(q_values.mean().item())
        loss_list.append(loss.item())
    end_time = time.time()
    elapsed_time = end_time - start_time
    return elapsed_time,q_values_list,loss_list


# function to extract batch from the buffers
def unpack_batch(batch):
    states = torch.cat(
        [
            torch.tensor(np.array(s).astype(np.float32)).float().unsqueeze(0)
            for s in batch.state
        ]
    )
    actions = torch.cat([torch.tensor(a).long().unsqueeze(0) for a in batch.action])
    rewards = torch.cat([torch.tensor(r).float().unsqueeze(0) for r in batch.reward])
    next_states = torch.cat(
        [
            torch.tensor(np.array(s).astype(np.float32)).float().unsqueeze(0)
            for s in batch.next_state
        ]
    )
    return states, actions, rewards, next_states


# function to evaluate results of testing phase
def evaluate_dqn(env, state, policy_net, target_net, device):
    episode_count = 0
    total_reward = 0
    solved = False
    while not solved and episode_count < 600:

        state = env.reset()
        state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
        episode_steps = 0
        while True:
            action = policy_net(state).max(1).indices.view(1, 1)

            next_state, reward, terminated, truncated, _ = env.step(action.item())
            if terminated:
                next_state = None
            else:
                next_state = torch.tensor(next_state, dtype=torch.float32, device=device).unsqueeze(0)
            total_reward += reward
            episode_steps += 1

            if terminated or truncated:
                break
            state = next_state

        if truncated:
            solved = True

        episode_count += 1

    total_reward = total_reward / episode_count
    return episode_count, total_reward


# main function for experiment
def run_experiment(num_trials, condition_name, csv_file, seed, memory, hyperparameter_dict):
    # Set the selected hyperparameters globally
    selected_hyperparameters = {
        "BATCH_SIZE": hyperparameter_dict["BATCH_SIZE"],
        "GAMMA": hyperparameter_dict["GAMMA"],
        "LR": hyperparameter_dict["LR"],
        "BATCH_NUM":hyperparameter_dict['BATCH_NUM'],
        "TAU":hyperparameter_dict['TAU'],
        'cql_weight':hyperparameter_dict['cql_weight'],
        'cql_temperature':hyperparameter_dict['cql_temperature'] ,
    }
    print(selected_hyperparameters['BATCH_SIZE'])
    print(f"Running experiment for condition: {condition_name}")
    # Initialize
    env = gym.make("CartPole-v1", new_step_api=True)
    # Get number of actions from gym action space
    action_dim = env.action_space.n
    # Get the number of state observations
    state = env.reset()
    state_dim = len(state)

    # initialize arrays to store results
    condition_episodes = []
    condition_rewards = []
    condition_times = []
    condition_q_values = []
    condition_losses = []
    for x in range(num_trials):
        # Set the seed for reproducibility within the trial
        new_seed = seed + x
        env.reset(seed=new_seed)
        np.random.seed(new_seed)
        torch.manual_seed(new_seed)
        random.seed(new_seed)
        # Initialize DQN, target network, and optimizer
        dqn = DQN(state_dim, action_dim, selected_hyperparameters).to(device)
        target_net = DQN(state_dim, action_dim, selected_hyperparameters).to(device)
        target_net.load_state_dict(dqn.state_dict())
        #optimizer = optim.Adam(dqn.parameters(), lr=selected_hyperparameters['LR'], amsgrad=True)
        optimizer = optim.RMSprop(dqn.parameters(), lr=selected_hyperparameters['LR'])
        # Train the DQN
        print("Training DQN: ", condition_name)
        train_time,q_values,loss = train_dqn(dqn, target_net, memory, optimizer, device, selected_hyperparameters)
        condition_times.append(train_time)
        condition_q_values.append(q_values)
        condition_losses.append(loss)
        state = env.reset()
        # Evaluate the DQN
        episodes, rewards = evaluate_dqn(env, state, dqn, target_net, device)
        print(
            f"Solved in {episodes} episodes for condition: {condition_name}, trial: {x}"
        )
        condition_episodes.append(episodes)
        condition_rewards.append(rewards)
        print('rewards: ', rewards)
        print('time: ', train_time)
        # reset state for gym, weights for dqn
        state = env.reset()


    # visualize q values and loss
    visualize_Q_results(condition_q_values, condition_losses, condition_name)

    return condition_episodes, condition_rewards, condition_times


#BATCH_SIZE': 256, 'BATCH_NUM': 200, 'GAMMA': 0.99, 'LR': 0.0001, 'TAU': 0.0005, 'cql_weight': 0.1, 'cql_temperature': 1
# Define the hyperparameter search space
hyperparameters = {
    "BATCH_SIZE": [256],
    "BATCH_NUM": [200],
    "GAMMA": [0.99],
    "LR": [0.0001],
    "TAU": [0.0005],
    'cql_weight':[0.1],
    'cql_temperature':[1],
}
# files
CSV_FILE_BASE = "/content/drive/MyDrive/data/tuning.csv"

# Set the number of trials for each hyperparameter combination
num_trials = 10

#function for hyperparamter tuning
def hyperparameter_tuning(condition, csv_file, memory):
    top_combos = []
    top_episodes = []
    seed = 0
    print('seed: ', seed)
    for hyperparameter_combination in itertools.product(*hyperparameters.values()):
        hyperparameter_dict = dict(zip(hyperparameters.keys(), hyperparameter_combination))

        print(f"\nHyperparameter Combination: {hyperparameter_dict}")

        mean_episodes = []

        condition_episodes, _, _ = run_experiment(num_trials, condition, csv_file, seed, memory,hyperparameter_dict)

        mean_episodes.append(np.mean(condition_episodes, axis=0))
        average_mean_episodes = np.mean(mean_episodes, axis=0)
        top_combos.append(hyperparameter_dict)
        top_episodes.append(average_mean_episodes)

    # Find the top 5 combinations based on the average mean episodes
    top_5_indices = np.argsort(top_episodes)[:5]
    top_5_combos = [top_combos[i] for i in top_5_indices]

    return top_5_combos

# main code for hyperparameter tuning
def main_hyperparameter_tuning():
    conditions = {
          "Baseline": CSV_FILE_BASE,
      }


    for condition, csv_file in conditions.items():
        print(f"\nRunning hyperparameter tuning for condition: {condition}")
        print("Extracting from dataset....")
        dataset = ReplayBufferDataset(csv_file)
        print("Creating memory buffer....")
        memory = ReplayBuffer(dataset)
        top_combos = hyperparameter_tuning(condition, csv_file,memory)

        print("\nTop 5 Performing Hyperparameter Combinations:")
        for i, combo in enumerate(top_combos, 1):
            print(f"{i}. {combo}")

def visualize_Q_results(q_values_list_per_condition, losses_list_per_condition, condition_name):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    for i, q_values_list in enumerate(q_values_list_per_condition):
        plt.plot(q_values_list, label=f'Trial {i + 1}')
    plt.title(f'Q-value Growth Over Iterations - {condition_name}')
    plt.xlabel('batch_num')
    plt.ylabel('Q-value')
    plt.legend()

    plt.subplot(1, 2, 2)
    for i, losses_list in enumerate(losses_list_per_condition):
        plt.plot(losses_list, label=f'Trial {i + 1}')
    plt.title(f'Loss Over Iterations - {condition_name}')
    plt.xlabel('batch_num')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main_hyperparameter_tuning()

# %%
# mountain car main experiment
# Adapted from the Reinforcement Learning (DQN) Tutorial by
# [Adam Paszke] https://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html
import gym
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import namedtuple
from torch.utils.data import Dataset, DataLoader
import numpy as np
import random
import random
import matplotlib.pyplot as plt
import matplotlib
import warnings
import time
from scipy.stats import mannwhitneyu
from tabulate import tabulate
import itertools
import math

warnings.filterwarnings("ignore", category=UserWarning)


# BATCH_SIZE is the number of transitions sampled from the replay buffer
# GAMMA makes rewards from the uncertain far future less
# important for our agent than the ones in the near future that it can be fairly confident about
# LR is the learning rate of the ``AdamW`` optimizer
# NUM_BATCH IS number of batch retrieve for training
# TAU is the update rate of the target network
BATCH_SIZE = 256
GAMMA = 0.99
LR = 1e-4
NUM_BATCH = 600
TAU = 0.0005
# files
CSV_FILE_BASE = "/content/drive/MyDrive/m_data/mountaincar_data.csv"
CSV_FILE_ADV = "/content/drive/MyDrive/m_data/augmented_data_adv.csv"
CSV_FILE_GAU = "/content/drive/MyDrive/m_data/augmented_data_gaussian.csv"
CSV_FILE_UNI = "/content/drive/MyDrive/m_data/augmented_data_uniform.csv"
CSV_STACK_ADV = "/content/drive/MyDrive/m_data/combined_adv.csv"
CSV_STACK_GAU = "/content/drive/MyDrive/m_data/combined_gauss.csv"
CSV_STACK_UNI = "/content/drive/MyDrive/m_data/combined_uniform.csv"
CSV_STACK_UNI_ADV = "/content/drive/MyDrive/m_data/combined_adv_uniform.csv"
CSV_STACK_GAU_ADV = "/content/drive/MyDrive/m_data/combined_adv_gauss.csv"
CSV_COM_UNI_GAU = "/content/drive/MyDrive/m_data/add_gauss_uniform.csv"
CSV_COM_UNI_ADV = "/content/drive/MyDrive/m_data/add_adv_gauss.csv"
CSV_COM_GAU_ADV = "/content/drive/MyDrive/m_data/add_adv_uniform.csv"
CSV_COM_ALL = "/content/drive/MyDrive/m_data/add_all.csv"

Transition = namedtuple("Transition", ["state", "action", "next_state", "reward"])
# Check if GPU (CUDA) is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# function for extracting from csv file
class ReplayBufferDataset(Dataset):
    def __init__(self, csv_file):
        self.df = pd.read_csv(
            csv_file,
            dtype={
                "state0": float,
                "state1": float,
                "Action": int,
                "Reward": int,
                "Terminated": bool,
            },
        )
        self.transitions = []

        for i in range(len(self.df)):
            state = self.df.loc[i, ["state0", "state1"]].values
            a = self.df.loc[i, "Action"]
            r = self.df.loc[i, "Reward"]
            t = self.df.loc[i, "Terminated"]

            if t :
                # Last step, termination/truncation = true
                next_state = [0,0]  # Placeholder for last step
            else:
                next_state = self.df.loc[
                    i + 1, ["state0", "state1"]
                ].values

            self.transitions.append(Transition(state, a, next_state, r))

    def __len__(self):
        return len(self.transitions)

    def __getitem__(self, idx):
        transition = self.transitions[idx]
        return Transition(
            transition.state,
            transition.action,
            transition.next_state,
            transition.reward,
        )


# Replay buffer
class ReplayBuffer:
    def __init__(self, dataset):
        self.buffer = dataset.transitions
        self.idx = 0

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        return Transition(*zip(*batch))

    def __len__(self):
        return len(self.buffer) * 2


class DQN(nn.Module):
    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()

        self.layer1 = nn.Linear(n_observations, BATCH_SIZE, bias=True)
        self.layer2 = nn.Linear(BATCH_SIZE, BATCH_SIZE, bias=True)
        self.layer3 = nn.Linear(BATCH_SIZE, BATCH_SIZE, bias=True)  # the representation layer
        self.layer4 = nn.Linear(BATCH_SIZE, n_actions, bias=True)  # the prediction layer

      # during optimization. Returns prediction
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.relu(self.layer3(x))
        return self.layer4(x)


# function for printing results
def print_results_table(condition, label, values):
    table_data = [
        ["Mean", np.mean(values)],
        ["Median", np.median(values)],
        ["Standard Deviation", np.std(values)],
        ["Minimum", np.min(values)],
        ["Maximum", np.max(values)],
    ]
    print(f"{label} for {condition}:")
    print(tabulate(table_data, headers=["Metric", "Value"], tablefmt="grid"))

# function for training dqn
def train_dqn(dqn, target_net, memory, optimizer, device):
    start_time = time.time()
    q_values_list = []  # Store Q-values
    loss_list = []  # Store loss
    num_batches = NUM_BATCH

    print('num_batch: ', num_batches)
    for transition in range(num_batches):
        # Sample batch from buffer
        batch = memory.sample(BATCH_SIZE)

        # Unpack batch
        states, actions, rewards, next_states = unpack_batch(batch)

        # Apply CUDA
        states, actions, rewards, next_states = (
            states.to(device),
            actions.to(device),
            rewards.to(device),
            next_states.to(device),
        )

        # Get Q values for current states
        q_values = dqn(states).gather(1, actions.view(-1, 1))

        # Calculate target Q values
        with torch.no_grad():
            if next_states.size(0) > 0:
                max_next_q = target_net(next_states).max(1)[0]
                target_q = rewards + GAMMA * max_next_q.detach()

        # Calculate loss
        '''
        loss_fn = nn.SmoothL1Loss()
        loss = loss_fn(q_values, target_q)
        '''
        # CQL Loss
        q_value_estimation_actions = dqn(states).max(1)[1].view(-1, 1)
        next_q_values = dqn(next_states).detach()
        next_q_values_selected = next_q_values.gather(1, q_value_estimation_actions)

        cql_temperature =  1.0
        cql_weight =  0.1

        loss = F.mse_loss(q_values, target_q) + cql_weight * F.mse_loss(cql_temperature * q_values, next_q_values_selected)

        # Optimize
        optimizer.zero_grad()
        loss.backward()
        # In-place gradient clipping
        torch.nn.utils.clip_grad_value_(dqn.parameters(), 10)
        optimizer.step()
        # soft update
        target_net_state_dict = target_net.state_dict()
        policy_net_state_dict = dqn.state_dict()
        for key in policy_net_state_dict:
            target_net_state_dict[key] = policy_net_state_dict[key]*TAU + target_net_state_dict[key]*(1-TAU)
        target_net.load_state_dict(target_net_state_dict)
        # Store Q-values and loss
        q_values_list.append(q_values.mean().item())
        loss_list.append(loss.item())

    end_time = time.time()
    elapsed_time = end_time - start_time
    return elapsed_time,q_values_list,loss_list

# function to extract batch from the buffers
def unpack_batch(batch):
    states = torch.cat(
        [
            torch.tensor(np.array(s).astype(np.float32)).float().unsqueeze(0)
            for s in batch.state
        ]
    )
    actions = torch.cat([torch.tensor(a).long().unsqueeze(0) for a in batch.action])
    rewards = torch.cat([torch.tensor(r).float().unsqueeze(0) for r in batch.reward])
    next_states = torch.cat(
        [
            torch.tensor(np.array(s).astype(np.float32)).float().unsqueeze(0)
            for s in batch.next_state
        ]
    )
    return states, actions, rewards, next_states

# function to evaluate results of testing phase
def evaluate_dqn(env, state, policy_net, target_net, device):
    episode_count = 0
    total_reward = 0
    solved = False

    while not solved and episode_count < 300:
        state = env.reset()
        state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
        episode_steps = 0
        while True:
            action = policy_net(state).max(1)[1].view(1, 1)
            next_state, reward, terminated, truncated, _ = env.step(action.item())
            next_state = torch.tensor(next_state, dtype=torch.float32, device=device).unsqueeze(0)
            total_reward += reward
            episode_steps += 1

            if terminated or truncated:
                break
            state = next_state

        if terminated:
            solved = True

        episode_count += 1

    total_reward = total_reward / episode_count
    return episode_count, total_reward



# main function for experiment
def run_experiment(num_trials, condition_name, csv_file, seed):
    print(f"Running experiment for condition: {condition_name}")
    print("Extracting from dataset....")
    dataset = ReplayBufferDataset(csv_file)
    print("Creating memory buffer....")
    memory = ReplayBuffer(dataset)
    # Initialize
    env = gym.make("MountainCar-v0", new_step_api=True)
    # Get number of actions from gym action space
    action_dim = env.action_space.n
    # Get the number of state observations
    state = env.reset()
    state_dim = len(state)


    # initialize arrays to store results
    condition_episodes = []
    condition_rewards = []
    condition_times = []
    condition_q_values = []
    condition_losses = []
    for x in range(num_trials):
        # Set the seed for reproducibility within the trial
        new_seed = seed + x
        env.reset(seed=new_seed)
        np.random.seed(new_seed)
        torch.manual_seed(new_seed)
        random.seed(new_seed)
        # Initialize DQN, target network, and optimizer
        dqn = DQN(state_dim, action_dim).to(device)
        target_net = DQN(state_dim, action_dim).to(device)
        target_net.load_state_dict(dqn.state_dict())
        optimizer = optim.RMSprop(dqn.parameters(), lr=LR)

        # Train the DQN
        print("Training DQN: ", condition_name)
        train_time,q_values,losses = train_dqn(dqn, target_net, memory, optimizer, device)
        condition_times.append(train_time)
        condition_q_values.append(q_values)
        condition_losses.append(losses)
        state = env.reset()
        # Evaluate the DQN
        episodes, rewards = evaluate_dqn(env, state, dqn, target_net, device)
        print(
            f"Solved in {episodes} episodes for condition: {condition_name}, trial: {x}"
        )
        condition_episodes.append(episodes)
        condition_rewards.append(rewards)
        print('rewards: ', rewards)
        print('time: ', train_time)
        # reset state for gym, weights for dqn
        state = env.reset()
        dqn.apply(weight_reset)
        target_net.apply(weight_reset)

    # visualize q values and loss
    visualize_Q_results(condition_q_values, condition_losses, condition_name)

    return condition_episodes, condition_rewards, condition_times


def perform_mannwhitneyu_test(
    condition1, result1, condition2, result2, alpha, num_comparisons
):
    # Mann-Whitney U Test for Rewards
    result = mannwhitneyu(result1["mean"], result2["mean"], alternative="greater")

    print(f"\nMann-Whitney U Test for {condition1} vs {condition2}:")
    print(f"U statistic: {result.statistic}")
    print(f"p-value: {result.pvalue}")

    # Bonferroni Correction
    adjusted_alpha = alpha / num_comparisons

    # Decide if statistically significant after Bonferroni Correction
    if result.pvalue < adjusted_alpha:
        print(
            f"The mean reward for {condition1} is statistically significantly greater than the mean reward for {condition2} after Bonferroni Correction (alpha={adjusted_alpha})."
        )
    else:
        print(
            f"The mean reward for {condition1} is NOT statistically significantly greater than the mean reward for {condition2} after Bonferroni Correction (alpha={adjusted_alpha})."
        )

def main():
    # setting up different conditions for testing
    '''
        "Baseline": CSV_FILE_BASE,
        "Gaussian": CSV_STACK_GAU,
        "Adv": CSV_STACK_ADV,
        "Uniform": CSV_STACK_UNI,
        "AdvUniform": CSV_STACK_UNI_ADV,
        "AdvGaussian": CSV_STACK_GAU_ADV,
        "COMB_GaussianUniform": CSV_COM_UNI_GAU,
        "COMB_AdvUniform": CSV_COM_UNI_ADV,
        "COMB_AdvGaussian": CSV_COM_GAU_ADV,
        "COMB_ALL": CSV_COM_ALL,
    '''
    conditions = {
        "Baseline": CSV_FILE_BASE,
        "Gaussian": CSV_STACK_GAU,
        "Adv": CSV_STACK_ADV,
        "Uniform": CSV_STACK_UNI,
        "AdvUni": CSV_STACK_UNI_ADV,
        "AdvGaus": CSV_STACK_GAU_ADV,
        "C_GausUni": CSV_COM_UNI_GAU,
        "C_AdvsUni": CSV_COM_UNI_ADV,
        "C_AdvGaus": CSV_COM_GAU_ADV,
        "C_ALL": CSV_COM_ALL,
    }
    print(conditions)
    num_trials = 5
    #888 is seed used
    #seed = np.random.randint(10000)  # Set a random seed for reproducibility across different conditions
    seed = 888
    print('seed: ', seed)
    episode_results = {}
    episode_rewards = {}
    episode_times = {}

    for condition, csv_file in conditions.items():

        condition_episodes, condition_rewards, condition_times = run_experiment(
            num_trials, condition, csv_file, seed
        )

        episode_results[condition] = {
            "mean": np.mean(condition_episodes, axis=0),
            "std": np.std(condition_episodes, axis=0),
        }

        episode_rewards[condition] = {
            "mean": np.mean(condition_rewards, axis=0),
            "std": np.std(condition_rewards, axis=0),
        }

        episode_times[condition] = {
            "mean": np.mean(condition_times),
            "std": np.std(condition_times),
        }

        print_results_table(condition, "Episodes", condition_episodes)
        print_results_table(condition, "Rewards", condition_rewards)
        print_results_table(condition, "Time", condition_times)


    # Statistical test
    num_comparisons = len(episode_rewards)
    alpha = 0.05


    for condition1, result1 in episode_rewards.items():
        for condition2, result2 in episode_rewards.items():
            # Avoid redundant comparisons and ensure each pair is tested only once
            if condition1 != condition2:
                # Perform Mann-Whitney U test
                perform_mannwhitneyu_test(condition1, result1, condition2, result2, alpha, num_comparisons)



    # Visualize results
    visualize_results(episode_results, "Episodes")
    visualize_results(episode_rewards, "Rewards")
    visualize_results(episode_times, "Time")


def Avisualize_results(results_dict, ylabel):
    colors = matplotlib.cm.rainbow(np.linspace(0, 1, len(results_dict)))
    plt.figure(figsize=(15, 8))

    for i, (condition, result) in enumerate(results_dict.items()):
        color = colors[i]
        plt.hist(result["mean"], alpha=0.7, label=f"{condition} (Mean)", color=color)

    plt.title(f"Distribution of Mean {ylabel}")
    plt.xlabel("Mean Value")
    plt.ylabel("Frequency")
    plt.legend()
    plt.show()

def visualize_results(results_dict, ylabel):
    colors = matplotlib.cm.rainbow(np.linspace(0, 1, len(results_dict)))
    plt.figure(figsize=(15, 8))

    conditions = list(results_dict.keys())
    mean_values = [result["mean"] for result in results_dict.values()]

    plt.bar(conditions, mean_values, color=colors, alpha=0.7)

    plt.title(f"Mean {ylabel} for Different Conditions")
    plt.xlabel("Conditions")
    plt.ylabel(f"Mean {ylabel}")
    plt.show()

def visualize_Q_results(q_values_list_per_condition, losses_list_per_condition, condition_name):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    for i, q_values_list in enumerate(q_values_list_per_condition):
        plt.plot(q_values_list, label=f'Trial {i + 1}')
    plt.title(f'Q-value Growth Over Iterations - {condition_name}')
    plt.xlabel('Iteration')
    plt.ylabel('Q-value')
    plt.legend()

    plt.subplot(1, 2, 2)
    for i, losses_list in enumerate(losses_list_per_condition):
        plt.plot(losses_list, label=f'Trial {i + 1}')
    plt.title(f'Loss Over Iterations - {condition_name}')
    plt.xlabel('Iteration')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'Baseline': '/content/drive/MyDrive/m_data/mountaincar_data.csv', 'Gaussian': '/content/drive/MyDrive/m_data/combined_gauss.csv', 'Adv': '/content/drive/MyDrive/m_data/combined_adv.csv', 'Uniform': '/content/drive/MyDrive/m_data/combined_uniform.csv', 'AdvUni': '/content/drive/MyDrive/m_data/combined_adv_uniform.csv', 'AdvGaus': '/content/drive/MyDrive/m_data/combined_adv_gauss.csv', 'C_GausUni': '/content/drive/MyDrive/m_data/add_gauss_uniform.csv', 'C_AdvsUni': '/content/drive/MyDrive/m_data/add_adv_gauss.csv', 'C_AdvGaus': '/content/drive/MyDrive/m_data/add_adv_uniform.csv', 'C_ALL': '/content/drive/MyDrive/m_data/add_all.csv'}
# seed:  888
# Running experiment for condition: Baseline
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  Baseline
# num_batch:  600
# Solved in 300 episodes for condition: Baseline, trial: 0
# rewards:  -200.0
# time:  11.769829273223877
# Training DQN:  Baseline
# num_batch:  600
# Solved in 300 episodes for condition: Baseline, trial: 1
# rewards:  -200.0
# time:  11.72520112991333
# Training DQN:  Baseline
# num_batch:  600
# Solved in 300 episodes for condition: Baseline, trial: 2
# rewards:  -200.0
# time:  11.670597553253174
# Training DQN:  Baseline
# num_batch:  600
# Solved in 1 episodes for condition: Baseline, trial: 3
# rewards:  -180.0
# time:  10.878274202346802
# Training DQN:  Baseline
# num_batch:  600
# Solved in 300 episodes for condition: Baseline, trial: 4
# rewards:  -200.0
# time:  11.898196697235107
# Episodes for Baseline:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |   240.2 |
# +--------------------+---------+
# | Median             |   300   |
# +--------------------+---------+
# | Standard Deviation |   119.6 |
# +--------------------+---------+
# | Minimum            |     1   |
# +--------------------+---------+
# | Maximum            |   300   |
# +--------------------+---------+
# Rewards for Baseline:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |    -196 |
# +--------------------+---------+
# | Median             |    -200 |
# +--------------------+---------+
# | Standard Deviation |       8 |
# +--------------------+---------+
# | Minimum            |    -200 |
# +--------------------+---------+
# | Maximum            |    -180 |
# +--------------------+---------+
# Time for Baseline:
# +--------------------+-----------+
# | Metric             |     Value |
# +====================+===========+
# | Mean               | 11.5884   |
# +--------------------+-----------+
# | Median             | 11.7252   |
# +--------------------+-----------+
# | Standard Deviation |  0.362944 |
# +--------------------+-----------+
# | Minimum            | 10.8783   |
# +--------------------+-----------+
# | Maximum            | 11.8982   |
# +--------------------+-----------+
# Running experiment for condition: Gaussian
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  Gaussian
# num_batch:  600
# Solved in 300 episodes for condition: Gaussian, trial: 0
# rewards:  -200.0
# time:  11.862569570541382
# Training DQN:  Gaussian
# num_batch:  600
# Solved in 300 episodes for condition: Gaussian, trial: 1
# rewards:  -200.0
# time:  11.679714441299438
# Training DQN:  Gaussian
# num_batch:  600
# Solved in 300 episodes for condition: Gaussian, trial: 2
# rewards:  -200.0
# time:  11.494642972946167
# Training DQN:  Gaussian
# num_batch:  600
# Solved in 300 episodes for condition: Gaussian, trial: 3
# rewards:  -200.0
# time:  11.04539704322815
# Training DQN:  Gaussian
# num_batch:  600
# Solved in 300 episodes for condition: Gaussian, trial: 4
# rewards:  -200.0
# time:  12.042206048965454
# Episodes for Gaussian:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |     300 |
# +--------------------+---------+
# | Median             |     300 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |     300 |
# +--------------------+---------+
# | Maximum            |     300 |
# +--------------------+---------+
# Rewards for Gaussian:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |    -200 |
# +--------------------+---------+
# | Median             |    -200 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |    -200 |
# +--------------------+---------+
# | Maximum            |    -200 |
# +--------------------+---------+
# Time for Gaussian:
# +--------------------+-----------+
# | Metric             |     Value |
# +====================+===========+
# | Mean               | 11.6249   |
# +--------------------+-----------+
# | Median             | 11.6797   |
# +--------------------+-----------+
# | Standard Deviation |  0.342469 |
# +--------------------+-----------+
# | Minimum            | 11.0454   |
# +--------------------+-----------+
# | Maximum            | 12.0422   |
# +--------------------+-----------+
# Running experiment for condition: Adv
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  Adv
# num_batch:  600
# Solved in 300 episodes for condition: Adv, trial: 0
# rewards:  -200.0
# time:  11.66882038116455
# Training DQN:  Adv
# num_batch:  600
# Solved in 300 episodes for condition: Adv, trial: 1
# rewards:  -200.0
# time:  11.91162633895874
# Training DQN:  Adv
# num_batch:  600
# Solved in 300 episodes for condition: Adv, trial: 2
# rewards:  -200.0
# time:  11.471166372299194
# Training DQN:  Adv
# num_batch:  600
# Solved in 300 episodes for condition: Adv, trial: 3
# rewards:  -200.0
# time:  11.090441226959229
# Training DQN:  Adv
# num_batch:  600
# Solved in 300 episodes for condition: Adv, trial: 4
# rewards:  -200.0
# time:  11.884883165359497
# Episodes for Adv:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |     300 |
# +--------------------+---------+
# | Median             |     300 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |     300 |
# +--------------------+---------+
# | Maximum            |     300 |
# +--------------------+---------+
# Rewards for Adv:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |    -200 |
# +--------------------+---------+
# | Median             |    -200 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |    -200 |
# +--------------------+---------+
# | Maximum            |    -200 |
# +--------------------+---------+
# Time for Adv:
# +--------------------+-----------+
# | Metric             |     Value |
# +====================+===========+
# | Mean               | 11.6054   |
# +--------------------+-----------+
# | Median             | 11.6688   |
# +--------------------+-----------+
# | Standard Deviation |  0.303021 |
# +--------------------+-----------+
# | Minimum            | 11.0904   |
# +--------------------+-----------+
# | Maximum            | 11.9116   |
# +--------------------+-----------+
# Running experiment for condition: Uniform
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  Uniform
# num_batch:  600
# Solved in 300 episodes for condition: Uniform, trial: 0
# rewards:  -200.0
# time:  11.703517198562622
# Training DQN:  Uniform
# num_batch:  600
# Solved in 300 episodes for condition: Uniform, trial: 1
# rewards:  -200.0
# time:  11.807587385177612
# Training DQN:  Uniform
# num_batch:  600
# Solved in 300 episodes for condition: Uniform, trial: 2
# rewards:  -200.0
# time:  11.824103116989136
# Training DQN:  Uniform
# num_batch:  600
# Solved in 300 episodes for condition: Uniform, trial: 3
# rewards:  -200.0
# time:  11.27549934387207
# Training DQN:  Uniform
# num_batch:  600
# Solved in 300 episodes for condition: Uniform, trial: 4
# rewards:  -200.0
# time:  11.795928239822388
# Episodes for Uniform:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |     300 |
# +--------------------+---------+
# | Median             |     300 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |     300 |
# +--------------------+---------+
# | Maximum            |     300 |
# +--------------------+---------+
# Rewards for Uniform:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |    -200 |
# +--------------------+---------+
# | Median             |    -200 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |    -200 |
# +--------------------+---------+
# | Maximum            |    -200 |
# +--------------------+---------+
# Time for Uniform:
# +--------------------+-----------+
# | Metric             |     Value |
# +====================+===========+
# | Mean               | 11.6813   |
# +--------------------+-----------+
# | Median             | 11.7959   |
# +--------------------+-----------+
# | Standard Deviation |  0.207195 |
# +--------------------+-----------+
# | Minimum            | 11.2755   |
# +--------------------+-----------+
# | Maximum            | 11.8241   |
# +--------------------+-----------+
# Running experiment for condition: AdvUni
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  AdvUni
# num_batch:  600
# Solved in 300 episodes for condition: AdvUni, trial: 0
# rewards:  -200.0
# time:  11.817517042160034
# Training DQN:  AdvUni
# num_batch:  600
# Solved in 300 episodes for condition: AdvUni, trial: 1
# rewards:  -200.0
# time:  11.897383213043213
# Training DQN:  AdvUni
# num_batch:  600
# Solved in 300 episodes for condition: AdvUni, trial: 2
# rewards:  -200.0
# time:  11.977434158325195
# Training DQN:  AdvUni
# num_batch:  600
# Solved in 300 episodes for condition: AdvUni, trial: 3
# rewards:  -200.0
# time:  11.332343816757202
# Training DQN:  AdvUni
# num_batch:  600
# Solved in 300 episodes for condition: AdvUni, trial: 4
# rewards:  -200.0
# time:  11.245410680770874
# Episodes for AdvUni:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |     300 |
# +--------------------+---------+
# | Median             |     300 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |     300 |
# +--------------------+---------+
# | Maximum            |     300 |
# +--------------------+---------+
# Rewards for AdvUni:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |    -200 |
# +--------------------+---------+
# | Median             |    -200 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |    -200 |
# +--------------------+---------+
# | Maximum            |    -200 |
# +--------------------+---------+
# Time for AdvUni:
# +--------------------+-----------+
# | Metric             |     Value |
# +====================+===========+
# | Mean               | 11.654    |
# +--------------------+-----------+
# | Median             | 11.8175   |
# +--------------------+-----------+
# | Standard Deviation |  0.303641 |
# +--------------------+-----------+
# | Minimum            | 11.2454   |
# +--------------------+-----------+
# | Maximum            | 11.9774   |
# +--------------------+-----------+
# Running experiment for condition: AdvGaus
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  AdvGaus
# num_batch:  600
# Solved in 300 episodes for condition: AdvGaus, trial: 0
# rewards:  -200.0
# time:  11.694702625274658
# Training DQN:  AdvGaus
# num_batch:  600
# Solved in 300 episodes for condition: AdvGaus, trial: 1
# rewards:  -200.0
# time:  11.78252387046814
# Training DQN:  AdvGaus
# num_batch:  600
# Solved in 300 episodes for condition: AdvGaus, trial: 2
# rewards:  -200.0
# time:  11.885329008102417
# Training DQN:  AdvGaus
# num_batch:  600
# Solved in 300 episodes for condition: AdvGaus, trial: 3
# rewards:  -200.0
# time:  11.229895830154419
# Training DQN:  AdvGaus
# num_batch:  600
# Solved in 300 episodes for condition: AdvGaus, trial: 4
# rewards:  -200.0
# time:  11.219141483306885
# Episodes for AdvGaus:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |     300 |
# +--------------------+---------+
# | Median             |     300 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |     300 |
# +--------------------+---------+
# | Maximum            |     300 |
# +--------------------+---------+
# Rewards for AdvGaus:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |    -200 |
# +--------------------+---------+
# | Median             |    -200 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |    -200 |
# +--------------------+---------+
# | Maximum            |    -200 |
# +--------------------+---------+
# Time for AdvGaus:
# +--------------------+-----------+
# | Metric             |     Value |
# +====================+===========+
# | Mean               | 11.5623   |
# +--------------------+-----------+
# | Median             | 11.6947   |
# +--------------------+-----------+
# | Standard Deviation |  0.282357 |
# +--------------------+-----------+
# | Minimum            | 11.2191   |
# +--------------------+-----------+
# | Maximum            | 11.8853   |
# +--------------------+-----------+
# Running experiment for condition: C_GausUni
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  C_GausUni
# num_batch:  600
# Solved in 300 episodes for condition: C_GausUni, trial: 0
# rewards:  -200.0
# time:  11.940789699554443
# Training DQN:  C_GausUni
# num_batch:  600
# Solved in 300 episodes for condition: C_GausUni, trial: 1
# rewards:  -200.0
# time:  11.8364839553833
# Training DQN:  C_GausUni
# num_batch:  600
# Solved in 300 episodes for condition: C_GausUni, trial: 2
# rewards:  -200.0
# time:  12.372304916381836
# Training DQN:  C_GausUni
# num_batch:  600
# Solved in 300 episodes for condition: C_GausUni, trial: 3
# rewards:  -200.0
# time:  10.937228202819824
# Training DQN:  C_GausUni
# num_batch:  600
# Solved in 300 episodes for condition: C_GausUni, trial: 4
# rewards:  -200.0
# time:  11.611407279968262
# Episodes for C_GausUni:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |     300 |
# +--------------------+---------+
# | Median             |     300 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |     300 |
# +--------------------+---------+
# | Maximum            |     300 |
# +--------------------+---------+
# Rewards for C_GausUni:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |    -200 |
# +--------------------+---------+
# | Median             |    -200 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |    -200 |
# +--------------------+---------+
# | Maximum            |    -200 |
# +--------------------+---------+
# Time for C_GausUni:
# +--------------------+-----------+
# | Metric             |     Value |
# +====================+===========+
# | Mean               | 11.7396   |
# +--------------------+-----------+
# | Median             | 11.8365   |
# +--------------------+-----------+
# | Standard Deviation |  0.471256 |
# +--------------------+-----------+
# | Minimum            | 10.9372   |
# +--------------------+-----------+
# | Maximum            | 12.3723   |
# +--------------------+-----------+
# Running experiment for condition: C_AdvsUni
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  C_AdvsUni
# num_batch:  600
# Solved in 300 episodes for condition: C_AdvsUni, trial: 0
# rewards:  -200.0
# time:  11.81879472732544
# Training DQN:  C_AdvsUni
# num_batch:  600
# Solved in 300 episodes for condition: C_AdvsUni, trial: 1
# rewards:  -200.0
# time:  11.82314682006836
# Training DQN:  C_AdvsUni
# num_batch:  600
# Solved in 300 episodes for condition: C_AdvsUni, trial: 2
# rewards:  -200.0
# time:  11.63767147064209
# Training DQN:  C_AdvsUni
# num_batch:  600
# Solved in 300 episodes for condition: C_AdvsUni, trial: 3
# rewards:  -200.0
# time:  10.902503967285156
# Training DQN:  C_AdvsUni
# num_batch:  600
# Solved in 300 episodes for condition: C_AdvsUni, trial: 4
# rewards:  -200.0
# time:  11.998549222946167
# Episodes for C_AdvsUni:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |     300 |
# +--------------------+---------+
# | Median             |     300 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |     300 |
# +--------------------+---------+
# | Maximum            |     300 |
# +--------------------+---------+
# Rewards for C_AdvsUni:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |    -200 |
# +--------------------+---------+
# | Median             |    -200 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |    -200 |
# +--------------------+---------+
# | Maximum            |    -200 |
# +--------------------+---------+
# Time for C_AdvsUni:
# +--------------------+-----------+
# | Metric             |     Value |
# +====================+===========+
# | Mean               | 11.6361   |
# +--------------------+-----------+
# | Median             | 11.8188   |
# +--------------------+-----------+
# | Standard Deviation |  0.384161 |
# +--------------------+-----------+
# | Minimum            | 10.9025   |
# +--------------------+-----------+
# | Maximum            | 11.9985   |
# +--------------------+-----------+
# Running experiment for condition: C_AdvGaus
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  C_AdvGaus
# num_batch:  600
# Solved in 300 episodes for condition: C_AdvGaus, trial: 0
# rewards:  -200.0
# time:  12.104948997497559
# Training DQN:  C_AdvGaus
# num_batch:  600
# Solved in 300 episodes for condition: C_AdvGaus, trial: 1
# rewards:  -200.0
# time:  11.85188913345337
# Training DQN:  C_AdvGaus
# num_batch:  600
# Solved in 300 episodes for condition: C_AdvGaus, trial: 2
# rewards:  -200.0
# time:  11.023272037506104
# Training DQN:  C_AdvGaus
# num_batch:  600
# Solved in 300 episodes for condition: C_AdvGaus, trial: 3
# rewards:  -200.0
# time:  11.626812219619751
# Training DQN:  C_AdvGaus
# num_batch:  600
# Solved in 300 episodes for condition: C_AdvGaus, trial: 4
# rewards:  -200.0
# time:  11.965043544769287
# Episodes for C_AdvGaus:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |     300 |
# +--------------------+---------+
# | Median             |     300 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |     300 |
# +--------------------+---------+
# | Maximum            |     300 |
# +--------------------+---------+
# Rewards for C_AdvGaus:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |    -200 |
# +--------------------+---------+
# | Median             |    -200 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |    -200 |
# +--------------------+---------+
# | Maximum            |    -200 |
# +--------------------+---------+
# Time for C_AdvGaus:
# +--------------------+-----------+
# | Metric             |     Value |
# +====================+===========+
# | Mean               | 11.7144   |
# +--------------------+-----------+
# | Median             | 11.8519   |
# +--------------------+-----------+
# | Standard Deviation |  0.379364 |
# +--------------------+-----------+
# | Minimum            | 11.0233   |
# +--------------------+-----------+
# | Maximum            | 12.1049   |
# +--------------------+-----------+
# Running experiment for condition: C_ALL
# Extracting from dataset....
# Creating memory buffer....
# Training DQN:  C_ALL
# num_batch:  600
# Solved in 300 episodes for condition: C_ALL, trial: 0
# rewards:  -200.0
# time:  11.691659450531006
# Training DQN:  C_ALL
# num_batch:  600
# Solved in 300 episodes for condition: C_ALL, trial: 1
# rewards:  -200.0
# time:  11.106455326080322
# Training DQN:  C_ALL
# num_batch:  600
# Solved in 300 episodes for condition: C_ALL, trial: 2
# rewards:  -200.0
# time:  11.905922651290894
# Training DQN:  C_ALL
# num_batch:  600
# Solved in 300 episodes for condition: C_ALL, trial: 3
# rewards:  -200.0
# time:  11.873168706893921
# Training DQN:  C_ALL
# num_batch:  600
# Solved in 300 episodes for condition: C_ALL, trial: 4
# rewards:  -200.0
# time:  11.825683832168579
# Episodes for C_ALL:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |     300 |
# +--------------------+---------+
# | Median             |     300 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |     300 |
# +--------------------+---------+
# | Maximum            |     300 |
# +--------------------+---------+
# Rewards for C_ALL:
# +--------------------+---------+
# | Metric             |   Value |
# +====================+=========+
# | Mean               |    -200 |
# +--------------------+---------+
# | Median             |    -200 |
# +--------------------+---------+
# | Standard Deviation |       0 |
# +--------------------+---------+
# | Minimum            |    -200 |
# +--------------------+---------+
# | Maximum            |    -200 |
# +--------------------+---------+
# Time for C_ALL:
# +--------------------+-----------+
# | Metric             |     Value |
# +====================+===========+
# | Mean               | 11.6806   |
# +--------------------+-----------+
# | Median             | 11.8257   |
# +--------------------+-----------+
# | Standard Deviation |  0.296198 |
# +--------------------+-----------+
# | Minimum            | 11.1065   |
# +--------------------+-----------+
# | Maximum            | 11.9059   |
# +--------------------+-----------+
#
# Mann-Whitney U Test for Baseline vs Gaussian:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Baseline vs Adv:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Baseline vs Uniform:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Baseline vs AdvUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Baseline vs AdvGaus:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Baseline vs C_GausUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Baseline vs C_AdvsUni:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Baseline vs C_AdvGaus:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Baseline vs C_ALL:
# U statistic: 1.0
# p-value: 0.5
# The mean reward for Baseline is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs Adv:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs Uniform:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs AdvUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs C_GausUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs C_AdvsUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs C_AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Gaussian vs C_ALL:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Gaussian is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs Gaussian:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs Uniform:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs AdvUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs C_GausUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs C_AdvsUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs C_AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Adv vs C_ALL:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Adv is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs Gaussian:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs Adv:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs AdvUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs C_GausUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs C_AdvsUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs C_AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for Uniform vs C_ALL:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for Uniform is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs Gaussian:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs Adv:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs Uniform:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs C_GausUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs C_AdvsUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs C_AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvUni vs C_ALL:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for AdvUni is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs Gaussian:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs Adv:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs Uniform:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs AdvUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs C_GausUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs C_AdvsUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs C_AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for AdvGaus vs C_ALL:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for AdvGaus is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs Gaussian:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs Adv:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs Uniform:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs AdvUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs C_AdvsUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs C_AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_GausUni vs C_ALL:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_GausUni is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs Gaussian:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs Adv:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs Uniform:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs AdvUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs C_GausUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs C_AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvsUni vs C_ALL:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvsUni is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs Gaussian:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs Adv:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs Uniform:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs AdvUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs C_GausUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs C_AdvsUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_AdvGaus vs C_ALL:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_AdvGaus is NOT statistically significantly greater than the mean reward for C_ALL after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs Baseline:
# U statistic: 0.0
# p-value: 1.0
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for Baseline after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs Gaussian:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for Gaussian after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs Adv:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for Adv after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs Uniform:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for Uniform after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs AdvUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for AdvUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for AdvGaus after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs C_GausUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for C_GausUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs C_AdvsUni:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for C_AdvsUni after Bonferroni Correction (alpha=0.005).
#
# Mann-Whitney U Test for C_ALL vs C_AdvGaus:
# U statistic: 0.5
# p-value: 1.0
# The mean reward for C_ALL is NOT statistically significantly greater than the mean reward for C_AdvGaus after Bonferroni Correction (alpha=0.005).

# %%
# hyperparameter tuning for mountain car
# Adapted from the Reinforcement Learning (DQN) Tutorial by
# [Adam Paszke] https://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html
import gym
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import namedtuple
from torch.utils.data import Dataset, DataLoader
import numpy as np
import random
import random
import matplotlib.pyplot as plt
import matplotlib
import warnings
import time
from scipy.stats import mannwhitneyu
from tabulate import tabulate
import itertools
import math
import torch.nn.functional as F

warnings.filterwarnings("ignore", category=UserWarning)



Transition = namedtuple("Transition", ["state", "action", "next_state", "reward", "terminated"])
# Check if GPU (CUDA) is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


class ReplayBufferDataset(Dataset):
    def __init__(self, csv_file):
        self.df = pd.read_csv(
            csv_file,
            dtype={
                "state0": float,
                "state1": float,
                "Action": int,
                "Reward": int,
                "Terminated": bool,
                "Truncated": bool,
            },
        )
        self.transitions = []

        for i in range(len(self.df)):
            state = self.df.loc[i, ["state0", "state1"]].values
            a = self.df.loc[i, "Action"]
            r = self.df.loc[i, "Reward"]
            t = self.df.loc[i, "Terminated"]
            tr = self.df.loc[i, "Truncated"]

            if t or tr:
                # Last step, termination,truncated = true
                next_state = [0,0] # Placeholder for last step
            else:
                next_state = self.df.loc[
                    i + 1, ["state0", "state1"]
                ].values

            self.transitions.append(Transition(state, a, next_state, r, t))

    def __len__(self):
        return len(self.transitions)

    def __getitem__(self, idx):
        transition = self.transitions[idx]
        return Transition(
            transition.state,
            transition.action,
            transition.next_state,
            transition.reward,
            transition.terminated,
        )


# Replay buffer
class ReplayBuffer:
    def __init__(self, dataset):
        self.buffer = dataset.transitions
        self.idx = 0

    def push(self, *args):
        """Save a transition"""
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        return Transition(*zip(*batch))

    def __len__(self):
        #return 50000
        return len(self.buffer)




class DQN(nn.Module):
    def __init__(self, n_observations, n_actions, selected_hyperparameters):
        super(DQN, self).__init__()

        self.layer1 = nn.Linear(n_observations, selected_hyperparameters['BATCH_SIZE'], bias=True)
        self.layer2 = nn.Linear(selected_hyperparameters['BATCH_SIZE'], selected_hyperparameters['BATCH_SIZE'], bias=True)
        #self.layer3 = nn.Linear(selected_hyperparameters['BATCH_SIZE'], selected_hyperparameters['BATCH_SIZE'], bias=True) # the representation layer
        self.layer4 = nn.Linear(selected_hyperparameters['BATCH_SIZE'], n_actions, bias=True)  # the prediction layer
        '''
        # xavier_uniform Weight Initialization: Set the initial values of the weights in a neural network,
        #aiming to address issues like vanishing or exploding gradients
        nn.init.xavier_uniform_(self.layer1.weight)
        nn.init.xavier_uniform_(self.layer2.weight)
        nn.init.xavier_uniform_(self.layer3.weight)
        nn.init.xavier_uniform_(self.layer4.weight)
        '''
      # during optimization. Returns prediction
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        #x = F.relu(self.layer3(x))
        return self.layer4(x)




# function for printing results
def print_results_table(condition, label, values):
    table_data = [
        ["Mean", np.mean(values)],
        ["Median", np.median(values)],
        ["Standard Deviation", np.std(values)],
        ["Minimum", np.min(values)],
        ["Maximum", np.max(values)],
    ]
    print(f"{label} for {condition}:")
    print(tabulate(table_data, headers=["Metric", "Value"], tablefmt="grid"))


# function for training dqn
def train_dqn(dqn, target_net, memory, optimizer, device, selected_hyperparameters):
    start_time = time.time()
    q_values_list = []  # Store Q-values
    loss_list = []  # Store loss
    for transition in range(selected_hyperparameters['BATCH_NUM']):
        # Sample batch from buffer
        batch = memory.sample(selected_hyperparameters['BATCH_SIZE'])

        # Unpack batch
        states, actions, rewards, next_states = unpack_batch(batch)

        # Apply CUDA
        states, actions, rewards, next_states = (
            states.to(device),
            actions.to(device),
            rewards.to(device),
            next_states.to(device),
        )

        # Get Q values for current states
        q_values = dqn(states).gather(1, actions.view(-1, 1))

        # Calculate target Q values
        with torch.no_grad():
            max_next_q = target_net(next_states).max(1)[0]
            target_q = rewards + selected_hyperparameters['GAMMA'] * max_next_q.detach()


        # Calculate loss
        '''
        loss_fn = nn.SmoothL1Loss()
        loss = loss_fn(q_values, target_q)
        '''
        # CQL Loss
        batch_size = selected_hyperparameters['BATCH_SIZE']
        q_value_estimation_actions = dqn(states).max(1)[1].view(-1, 1)
        next_q_values = dqn(next_states).detach()
        next_q_values_selected = next_q_values.gather(1, q_value_estimation_actions)
        cql_temperature = selected_hyperparameters['cql_temperature']
        cql_weight = selected_hyperparameters['cql_weight']
        loss = F.mse_loss(q_values, target_q) + cql_weight * F.mse_loss(cql_temperature * q_values, next_q_values_selected)

        # Optimize
        optimizer.zero_grad()
        loss.backward()
        max_norm = 10

        # Clip gradients to a maximum norm
        torch.nn.utils.clip_grad_value_(dqn.parameters(), max_norm)

        optimizer.step()

        # Soft update of the target network's weights
        target_net_state_dict = target_net.state_dict()
        policy_net_state_dict = dqn.state_dict()
        TAU = selected_hyperparameters['TAU']
        for key in policy_net_state_dict:
            target_net_state_dict[key] = policy_net_state_dict[key]*TAU + target_net_state_dict[key]*(1-TAU)
        target_net.load_state_dict(target_net_state_dict)
        # Store Q-values and loss
        q_values_list.append(q_values.mean().item())
        loss_list.append(loss.item())
    end_time = time.time()
    elapsed_time = end_time - start_time
    return elapsed_time,q_values_list,loss_list


# function to extract batch from the buffers
def unpack_batch(batch):
    states = torch.cat(
        [
            torch.tensor(np.array(s).astype(np.float32)).float().unsqueeze(0)
            for s in batch.state
        ]
    )
    actions = torch.cat([torch.tensor(a).long().unsqueeze(0) for a in batch.action])
    rewards = torch.cat([torch.tensor(r).float().unsqueeze(0) for r in batch.reward])
    next_states = torch.cat(
        [
            torch.tensor(np.array(s).astype(np.float32)).float().unsqueeze(0)
            for s in batch.next_state
        ]
    )
    return states, actions, rewards, next_states


# function to evaluate results of testing phase
def evaluate_dqn(env, state, policy_net, target_net, device):
    episode_count = 0
    total_reward = 0
    solved = False
    while not solved and episode_count < 300:

        state = env.reset()
        state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
        episode_steps = 0
        while True:
            action = policy_net(state).max(1).indices.view(1, 1)

            next_state, reward, terminated, truncated, _ = env.step(action.item())
            if terminated:
                next_state = None
            else:
                next_state = torch.tensor(next_state, dtype=torch.float32, device=device).unsqueeze(0)
            total_reward += reward
            episode_steps += 1
            if terminated or truncated:
                break
            state = next_state
        if terminated:
            solved = True
        episode_count += 1

    total_reward = total_reward / episode_count
    return episode_count, total_reward


# main function for experiment
def run_experiment(num_trials, condition_name, csv_file, seed, memory, hyperparameter_dict):
    # Set the selected hyperparameters globally
    selected_hyperparameters = {
        "BATCH_SIZE": hyperparameter_dict["BATCH_SIZE"],
        "GAMMA": hyperparameter_dict["GAMMA"],
        "LR": hyperparameter_dict["LR"],
        "BATCH_NUM":hyperparameter_dict['BATCH_NUM'],
        "TAU":hyperparameter_dict['TAU'],
        'cql_weight':hyperparameter_dict['cql_weight'],
        'cql_temperature':hyperparameter_dict['cql_temperature'] ,
    }
    print(selected_hyperparameters['BATCH_SIZE'])
    print(f"Running experiment for condition: {condition_name}")
    # Initialize
    env = gym.make("MountainCar-v0", new_step_api=True)
    # Get number of actions from gym action space
    action_dim = env.action_space.n
    # Get the number of state observations
    state = env.reset()
    state_dim = len(state)

    # initialize arrays to store results
    condition_episodes = []
    condition_rewards = []
    condition_times = []
    condition_q_values = []
    condition_losses = []
    for x in range(num_trials):
        # Set the seed for reproducibility within the trial
        new_seed = seed + x
        env.reset(seed=new_seed)
        np.random.seed(new_seed)
        torch.manual_seed(new_seed)
        random.seed(new_seed)
        # Initialize DQN, target network, and optimizer
        dqn = DQN(state_dim, action_dim, selected_hyperparameters).to(device)
        target_net = DQN(state_dim, action_dim, selected_hyperparameters).to(device)
        target_net.load_state_dict(dqn.state_dict())
        #optimizer = optim.Adam(dqn.parameters(), lr=selected_hyperparameters['LR'], amsgrad=True)
        optimizer = optim.RMSprop(dqn.parameters(), lr=selected_hyperparameters['LR'])
        # Train the DQN
        print("Training DQN: ", condition_name)
        train_time,q_values,loss = train_dqn(dqn, target_net, memory, optimizer, device, selected_hyperparameters)
        condition_times.append(train_time)
        condition_q_values.append(q_values)
        condition_losses.append(loss)
        state = env.reset()
        # Evaluate the DQN
        episodes, rewards = evaluate_dqn(env, state, dqn, target_net, device)
        print(
            f"Solved in {episodes} episodes for condition: {condition_name}, trial: {x}"
        )
        condition_episodes.append(episodes)
        condition_rewards.append(rewards)
        print('rewards: ', rewards)
        print('time: ', train_time)
        # reset state for gym, weights for dqn
        state = env.reset()


    # visualize q values and loss
    visualize_Q_results(condition_q_values, condition_losses, condition_name)

    return condition_episodes, condition_rewards, condition_times


#'BATCH_SIZE': 256, 'BATCH_NUM': 600, 'GAMMA': 0.99, 'LR': 0.0001, 'TAU': 0.0005, 'cql_weight': 0.1, 'cql_temperature': 1
# Define the hyperparameter search space
hyperparameters = {
    "BATCH_SIZE": [256,512],
    "BATCH_NUM": [200,400],
    "GAMMA": [0.99,0.999],
    "LR": [0.0001,0.0005,0.001],
    "TAU": [0.0005],
    'cql_weight':[0.1],
    'cql_temperature':[1],
}
# files
CSV_FILE_BASE = "/content/drive/MyDrive/m_data/tuning.csv"

# Set the number of trials for each hyperparameter combination
num_trials = 20

#function for hyperparamter tuning
def hyperparameter_tuning(condition, csv_file, memory):
    top_combos = []
    top_episodes = []
    seed = 0
    print('seed: ', seed)
    for hyperparameter_combination in itertools.product(*hyperparameters.values()):
        hyperparameter_dict = dict(zip(hyperparameters.keys(), hyperparameter_combination))

        print(f"\nHyperparameter Combination: {hyperparameter_dict}")

        mean_episodes = []

        condition_episodes, _, _ = run_experiment(num_trials, condition, csv_file, seed, memory,hyperparameter_dict)

        mean_episodes.append(np.mean(condition_episodes, axis=0))
        average_mean_episodes = np.mean(mean_episodes, axis=0)
        top_combos.append(hyperparameter_dict)
        top_episodes.append(average_mean_episodes)

    # Find the top 5 combinations based on the average mean episodes
    top_5_indices = np.argsort(top_episodes)[:5]
    top_5_combos = [top_combos[i] for i in top_5_indices]

    return top_5_combos

# main code for hyperparameter tuning
def main_hyperparameter_tuning():
    conditions = {
          "Baseline": CSV_FILE_BASE,
      }


    for condition, csv_file in conditions.items():
        print(f"\nRunning hyperparameter tuning for condition: {condition}")
        print("Extracting from dataset....")
        dataset = ReplayBufferDataset(csv_file)
        print("Creating memory buffer....")
        memory = ReplayBuffer(dataset)
        top_combos = hyperparameter_tuning(condition, csv_file,memory)

        print("\nTop 5 Performing Hyperparameter Combinations:")
        for i, combo in enumerate(top_combos, 1):
            print(f"{i}. {combo}")

def visualize_Q_results(q_values_list_per_condition, losses_list_per_condition, condition_name):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    for i, q_values_list in enumerate(q_values_list_per_condition):
        plt.plot(q_values_list, label=f'Trial {i + 1}')
    plt.title(f'Q-value Growth Over Iterations - {condition_name}')
    plt.xlabel('batch_num')
    plt.ylabel('Q-value')
    plt.legend()

    plt.subplot(1, 2, 2)
    for i, losses_list in enumerate(losses_list_per_condition):
        plt.plot(losses_list, label=f'Trial {i + 1}')
    plt.title(f'Loss Over Iterations - {condition_name}')
    plt.xlabel('batch_num')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main_hyperparameter_tuning()

# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
